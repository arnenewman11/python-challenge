# %%
import os
import pandas as pd
import numpy as np

# %%
#set up file paths
file_path1 = os.path.join("raw_data", "schools_complete.csv")
file_path2 = os.path.join("raw_data", "students_complete.csv")

# %%
#define files
file1 = pd.read_csv(file_path1)
file2 = pd.read_csv(file_path2)

# %%
#create dataframes
df_school = pd.DataFrame(file1)
df_stud = pd.DataFrame(file2)

# %%
#Change column headers in both dfs to allow for merge
df_school_sync = df_school.rename(columns={"name":"School Name"})
df_stud_sync = df_stud.rename(columns={"school":"School Name"})

df_stud_sync.head()
# Out:
#    Student ID               name gender grade        School Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#right join tables by School Name, including all student table rows
merged_data = pd.merge(df_school_sync, df_stud_sync, on="School Name", how="right")

#check out the merged table
merged_data.head()
# Out:
#    School ID        School Name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#                 name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
#create metrics
#count total # of schools by unique names
total_schools = merged_data["School Name"].nunique()

#count total students by length of names column
total_students = len(merged_data["name"])
total_students

#total budget by sum of 
total_budget = df_school_sync["budget"].sum()
total_budget

#calc average math & reading score
avg_math = merged_data["math_score"].mean()
#calc average math score
avg_reading = merged_data["reading_score"].mean()
avg_reading

#define passing level
pass_score = 70

#calculate number of students passing math and reading
reading_pass_stud = merged_data["reading_score"].loc[merged_data["reading_score"] > int(pass_score)].count()
math_pass_stud = merged_data["math_score"].loc[merged_data["math_score"] > int(pass_score)].count()

#calculate percentages
pct_passing_math = math_pass_stud / total_students
pct_passing_reading = reading_pass_stud/ total_students
avg_pass_rate = (pct_passing_reading + pct_passing_math) / 2
avg_pass_rate
# Out:
# 0.77681899412815936

# %%
district_summary = pd.DataFrame({"Total Schools":total_schools, "Total Students":total_students, "Total Budget":total_budget,
                                "Average Math Score":avg_math, "Average Reading Score":avg_reading, "% Passing Math":pct_passing_math, 
                                 "% Passing Reading":pct_passing_reading, "Overall Pass Rate":avg_pass_rate}, index=[0])
district_summary.head()
# Out:
#    % Passing Math  % Passing Reading  Average Math Score  \
# 0        0.723921           0.829717           78.985371
#
#    Average Reading Score  Overall Pass Rate  Total Budget  Total Schools  \
# 0               81.87784           0.776819      24649428             15
#
#    Total Students
# 0           39170

# %%
#UNNECESSARY... THIS IS THE HARD WAY (easy way is later)

#create new data frame to store school-level data
school_avg_data = merged_data.groupby(["School Name"]).mean()
school_avg_data_sorted = school_avg_data.sort_values("School ID")
school_avg_data_sorted.reset_index(inplace=True)
school_avg_data_sorted.head()
# Out:
#              School Name  School ID    size     budget  Student ID  \
# 0      Huang High School        0.0  2917.0  1910635.0      1458.0
# 1   Figueroa High School        1.0  2949.0  1884411.0      4391.0
# 2    Shelton High School        2.0  1761.0  1056600.0      6746.0
# 3  Hernandez High School        3.0  4635.0  3022020.0      9944.0
# 4    Griffin High School        4.0  1468.0   917500.0     12995.5
#
#    reading_score  math_score
# 0      81.182722   76.629414
# 1      81.158020   76.711767
# 2      83.725724   83.359455
# 3      80.934412   77.289752
# 4      83.816757   83.351499

# %%
#THIS IS IRFAN'S "SIMPLE" solution... I don't follow entirely, as the issue I've encountered is not generating this data but getting
#it into a data frame with other metrics... KEEP GOING!!!!

#get budget by school
#per_school_budget = merged_data.groupby(["School Name"]).mean()["budget"]
#per_school_budget

#calc avg reading score per school
#per_school_read_avg = merged_data.groupby(["School Name"]).mean()["reading_score"]
#per_school_read_avg

#school size
#per_school_students = merged.data.groupby(["School Name"]).mean()["size"]

#% group the data frame to show the number that passed math for each school... grouping by name caused problems so went with ID
#school_math_pass_only= merged_data.loc[(merged_data["math_score"] > 70)].groupby("School ID").count()



#per_school_counts = school_data_complete["school_name"].value_counts()

# %%
#I MIGHT NEED TO RE-DO THIS BY PULLING I FROM MERGED DATA... using original tables isn't really working... maybe sort?

#School-Level Metrics
school_names = df_school_sync["School Name"]

#designate school types
school_types = df_school_sync["type"]

#number of students by school
school_size = df_school_sync["size"]

#total budget by school
school_budget = df_school_sync["budget"]

#per student budget
per_student_budget = school_budget / school_size

#average math score
avg_school_math = school_avg_data["math_score"]

#average reading score
avg_school_reading = school_avg_data["reading_score"]

#% group the data frame to show the number that passed math for each school... grouping by name caused problems so went with ID
school_math_pass_only= merged_data.loc[(merged_data["math_score"] > 70)].groupby("School ID").count()

#create a list that is only the math scores per school (other columns gone)
school_math_pass_tot = school_math_pass_only["math_score"]

#calculate percentage passing math for each school
school_math_pass_pct = (school_math_pass_tot / school_size) *100

#% passing reading
#% group the data frame to show the number that passed reading for each school... grouping by name caused problems so went with ID
school_reading_pass_only= merged_data.loc[(merged_data["reading_score"] > 70)].groupby("School ID").count()

#create a list that is only the reading scores per school (other columns gone)
school_reading_pass_tot = school_reading_pass_only["reading_score"]

#calculate percentage passing reading for each school
school_reading_pass_pct = (school_reading_pass_tot / school_size) * 100

#%overall passing rate
school_overall_pass_rate = (school_math_pass_pct + school_reading_pass_pct) / 2

school_types_list = school_types.tolist()
print(school_types_list)

#Create a new data frame that stores all of it
school_summary_data = pd.DataFrame({
    "": school_names.tolist(),
    "School Type": school_types.tolist(),
    "Total Students": school_size.tolist(),
    "Total School Budget":school_budget.tolist(),
    "Per Student Budget":per_student_budget.tolist(),
    "Average Math Score":avg_school_math.tolist(),
    "Average Reading Score":avg_school_reading.tolist(),
    "% Passing Math":school_math_pass_pct.tolist(),
    "% Passing Reading":school_reading_pass_pct.tolist(),
    "% Overall Passing Rate":school_overall_pass_rate.tolist()
    }).sort_values("") 


school_summary_data.set_index("",inplace=True)

pretty_summary_data = school_summary_data

#format via mapping
school_summary_data["School Type"] = school_summary_data["School Type"]
school_summary_data["Total Students"] = school_summary_data["Total Students"].map("{:,}".format)
school_summary_data["Total School Budget"] = school_summary_data["Total School Budget"].map("${:,.0f}".format)
school_summary_data["Per Student Budget"] = school_summary_data["Per Student Budget"].map("${:.0f}".format)
school_summary_data["Average Math Score"] = school_summary_data["Average Math Score"].map("{:.1f}".format)
school_summary_data["Average Reading Score"] = school_summary_data["Average Reading Score"].map("{:.1f}".format)
school_summary_data["% Passing Math"] = school_summary_data["% Passing Math"].map("{:.2f}%".format)
school_summary_data["% Passing Reading"] = school_summary_data["% Passing Reading"].map("{:.1f}%".format)
school_summary_data["% Overall Passing Rate"] = school_summary_data["% Overall Passing Rate"].map("{:.2f}%".format)


#pretty_summary_data["School Type"] = school_summary_data["School Type"]
#pretty_summary_data["Total Students"] = school_summary_data["Total Students"].map("{:,}".format)
#pretty_summary_data["Total School Budget"] = school_summary_data["Total School Budget"].map("${:,.0f}".format)
#pretty_summary_data["Per Student Budget"] = school_summary_data["Per Student Budget"].map("${:.0f}".format)
#pretty_summary_data["Average Math Score"] = school_summary_data["Average Math Score"].map("{:.1f}".format)
#pretty_summary_data["Average Reading Score"] = school_summary_data["Average Reading Score"].map("{:.1f}".format)
#pretty_summary_data["% Passing Math"] = school_summary_data["% Passing Math"].map("{:.2f}%".format)
#pretty_summary_data["% Passing Reading"] = school_summary_data["% Passing Reading"].map("{:.1f}%".format)
#pretty_summary_data["% Overall Passing Rate"] = school_summary_data["% Overall Passing Rate"].map("{:.2f}%".format)

school_summary_data
#cols = school_summary_data.columns.values
# Out:
# ['District', 'District', 'Charter', 'District', 'Charter', 'Charter', 'Charter', 'District', 'Charter', 'Charter', 'Charter', 'District', 'District', 'District', 'Charter']
#                       % Overall Passing Rate % Passing Math % Passing Reading  \
#
# Bailey High School                    71.97%         64.63%             79.3%
# Cabrera High School                   91.71%         89.56%             93.9%
# Figueroa High School                  71.09%         63.75%             78.4%
# Ford High School                      71.63%         65.75%             77.5%
# Griffin High School                   91.55%         89.71%             93.4%
# Hernandez High School                 71.47%         64.75%             78.2%
# Holden High School                    91.69%         90.63%             92.7%
# Huang High School                     71.07%         63.32%             78.8%
# Johnson High School                   71.07%         63.85%             78.3%
# Pena High School                      91.94%         91.68%             92.2%
# Rodriguez High School                 70.91%         64.07%             77.7%
# Shelton High School                   91.25%         89.89%             92.6%
# Thomas High School                    91.56%         90.21%             92.9%
# Wilson High School                    92.09%         90.93%             93.3%
# Wright High School                    91.86%         90.28%             93.4%
#
#                       Average Math Score Average Reading Score  \
#
# Bailey High School                  76.6                  81.2
# Cabrera High School                 83.8                  83.8
# Figueroa High School                83.1                  84.0
# Ford High School                    83.3                  84.0
# Griffin High School                 83.4                  83.8
# Hernandez High School               77.1                  80.7
# Holden High School                  77.1                  81.0
# Huang High School                   77.0                  81.0
# Johnson High School                 83.4                  83.8
# Pena High School                    83.8                  84.0
# Rodriguez High School               83.4                  83.7
# Shelton High School                 76.7                  81.2
# Thomas High School                  83.7                  84.0
# Wilson High School                  77.3                  80.9
# Wright High School                  76.8                  80.7
#
#                       Per Student Budget School Type Total School Budget  \
#
# Bailey High School                  $628    District          $3,124,928
# Cabrera High School                 $582     Charter          $1,081,356
# Figueroa High School                $639    District          $1,884,411
# Ford High School                    $644    District          $1,763,916
# Griffin High School                 $625     Charter            $917,500
# Hernandez High School               $652    District          $3,022,020
# Holden High School                  $581     Charter            $248,087
# Huang High School                   $655    District          $1,910,635
# Johnson High School                 $650    District          $3,094,650
# Pena High School                    $609     Charter            $585,858
# Rodriguez High School               $637    District          $2,547,363
# Shelton High School                 $600     Charter          $1,056,600
# Thomas High School                  $638     Charter          $1,043,130
# Wilson High School                  $578     Charter          $1,319,574
# Wright High School                  $583     Charter          $1,049,400
#
#                       Total Students
#
# Bailey High School             4,976
# Cabrera High School            1,858
# Figueroa High School           2,949
# Ford High School               2,739
# Griffin High School            1,468
# Hernandez High School          4,635
# Holden High School               427
# Huang High School              2,917
# Johnson High School            4,761
# Pena High School                 962
# Rodriguez High School          3,999
# Shelton High School            1,761
# Thomas High School             1,635
# Wilson High School             2,283
# Wright High School             1,800

# %%
#Top performing schools by Passing rate

#sort from best to worst
schools_by_pass = school_summary_data.sort_values("% Overall Passing Rate", ascending=False)

#only display top 5 schools
top5_schools = schools_by_pass.iloc[0:5,:]

top5_schools
# Out:
#                     % Overall Passing Rate % Passing Math % Passing Reading  \
#
# Wilson High School                  92.09%         90.93%             93.3%
# Pena High School                    91.94%         91.68%             92.2%
# Wright High School                  91.86%         90.28%             93.4%
# Cabrera High School                 91.71%         89.56%             93.9%
# Holden High School                  91.69%         90.63%             92.7%
#
#                     Average Math Score Average Reading Score  \
#
# Wilson High School                77.3                  80.9
# Pena High School                  83.8                  84.0
# Wright High School                76.8                  80.7
# Cabrera High School               83.8                  83.8
# Holden High School                77.1                  81.0
#
#                     Per Student Budget School Type Total School Budget  \
#
# Wilson High School                $578     Charter          $1,319,574
# Pena High School                  $609     Charter            $585,858
# Wright High School                $583     Charter          $1,049,400
# Cabrera High School               $582     Charter          $1,081,356
# Holden High School                $581     Charter            $248,087
#
#                     Total Students
#
# Wilson High School           2,283
# Pena High School               962
# Wright High School           1,800
# Cabrera High School          1,858
# Holden High School             427

# %%
#Top performing schools by Passing rate

#sort from best to worst
worst_schools_by_pass = school_summary_data.sort_values("% Overall Passing Rate")

#only display top 5 schools
bottom5_schools = worst_schools_by_pass.iloc[0:5,:]

bottom5_schools
# Out:
#                       % Overall Passing Rate % Passing Math % Passing Reading  \
#
# Rodriguez High School                 70.91%         64.07%             77.7%
# Huang High School                     71.07%         63.32%             78.8%
# Johnson High School                   71.07%         63.85%             78.3%
# Figueroa High School                  71.09%         63.75%             78.4%
# Hernandez High School                 71.47%         64.75%             78.2%
#
#                       Average Math Score Average Reading Score  \
#
# Rodriguez High School               83.4                  83.7
# Huang High School                   77.0                  81.0
# Johnson High School                 83.4                  83.8
# Figueroa High School                83.1                  84.0
# Hernandez High School               77.1                  80.7
#
#                       Per Student Budget School Type Total School Budget  \
#
# Rodriguez High School               $637    District          $2,547,363
# Huang High School                   $655    District          $1,910,635
# Johnson High School                 $650    District          $3,094,650
# Figueroa High School                $639    District          $1,884,411
# Hernandez High School               $652    District          $3,022,020
#
#                       Total Students
#
# Rodriguez High School          3,999
# Huang High School              2,917
# Johnson High School            4,761
# Figueroa High School           2,949
# Hernandez High School          4,635

# %%
#Math scores by grade
grade9 = merged_data.loc[merged_data["grade"]=="9th",:].groupby("School Name")
avg_math_grade9 = grade9["math_score"].mean()

grade10 = merged_data.loc[merged_data["grade"]=="10th",:].groupby("School Name")
avg_math_grade10 = grade10["math_score"].mean()

grade11 = merged_data.loc[merged_data["grade"]=="11th",:].groupby("School Name")
avg_math_grade11 = grade11["math_score"].mean()

grade12 = merged_data.loc[merged_data["grade"]=="12th",:].groupby("School Name")
avg_math_grade12 = grade12["math_score"].mean()

#create a dataframe with the grades
math_by_grade = pd.DataFrame({
    "":school_names.tolist(),
    "9th": avg_math_grade9.tolist(),
    "10th": avg_math_grade10.tolist(),
    "11th": avg_math_grade11.tolist(),
    "12th": avg_math_grade12.tolist()
})

math_by_grade.set_index("",inplace=True)

# %%
#reading scores by grade
avg_reading_grade9 = grade9["reading_score"].mean()

avg_reading_grade10 = grade10["reading_score"].mean()

avg_reading_grade11 = grade11["reading_score"].mean()

avg_reading_grade12 = grade12["reading_score"].mean()

#create a dataframe with the grades
reading_by_grade = pd.DataFrame({
    "":school_names.tolist(),
    "9th": avg_reading_grade9.tolist(),
    "10th": avg_reading_grade10.tolist(),
    "11th": avg_reading_grade11.tolist(),
    "12th": avg_reading_grade12.tolist()
})

reading_by_grade.set_index("",inplace=True)

reading_by_grade
# Out:
#                             10th       11th       12th        9th
#
# Huang High School      80.907183  80.945643  80.912451  81.303155
# Figueroa High School   84.253219  83.788382  84.287958  83.676136
# Shelton High School    81.408912  80.640339  81.384863  81.198598
# Hernandez High School  81.262712  80.403642  80.662338  80.632653
# Griffin High School    83.706897  84.288089  84.013699  83.369193
# Wilson High School     80.660147  81.396140  80.857143  80.866860
# Cabrera High School    83.324561  83.815534  84.698795  83.677165
# Bailey High School     81.512386  81.417476  80.305983  81.290284
# Holden High School     80.773431  80.616027  81.227564  81.260714
# Pena High School       83.612000  84.335938  84.591160  83.807273
# Wright High School     80.629808  80.864811  80.376426  80.993127
# Rodriguez High School  83.441964  84.373786  82.781671  84.122642
# Johnson High School    84.254157  83.585542  83.831361  83.728850
# Ford High School       84.021452  83.764608  84.317673  83.939778
# Thomas High School     83.812757  84.156322  84.073171  83.833333

# %%
#school_summary_data["Per Student Budget"] = int(school_summary_data["Per Student Budget"])
school_summary_data['Per Student Budget'] = pd.to_numeric(school_summary_data['Per Student Budget'].replace("$",""))

school_summary_data['Average Reading Score'] = pd.to_numeric(school_summary_data['Average Reading Score'],'float')
school_summary_data['Average Math Score'] = pd.to_numeric(school_summary_data['Average Math Score'],'float')

#to numeric isn't working for these
school_summary_data['% Passing Math'] = pd.to_numeric(school_summary_data['% Passing Math'].str.replace("%", ""),'float')
school_summary_data['% Passing Reading'] = pd.to_numeric(school_summary_data['% Passing Reading'].str.replace("%", ""),'float')
school_summary_data['% Overall Passing Rate'] = pd.to_numeric(school_summary_data['% Overall Passing Rate'].str.replace("%", ""),'float')

# %%
#create performance bins by school size: small, medium, large (see binning exercise). Table sould include 
#school_summary_data["Per Student Budget"].min()

#max is $655, $min is 578
bins = [500,585,610,635,660]
bin_names = ["$0-585", "$585-610", "$610-635", "$635-660"]
#bin_names = ["super cheap", "cheap", "alright", "woohoo"]

#work from there...
#pd.cut()
#school_summary_data["% Overall Passing Rate"] = float(school_summary_data["% Overall Passing Rate"])

# Cut postTestScore and place the scores into bins
school_summary_data["Spending Ranges (Per Student)"] = pd.cut(school_summary_data["Per Student Budget"], bins, labels=bin_names)
school_summary_data.head()
# Out:
#                       % Overall Passing Rate  % Passing Math  \
#
# Bailey High School                     71.97           64.63
# Cabrera High School                    91.71           89.56
# Figueroa High School                   71.09           63.75
# Ford High School                       71.63           65.75
# Griffin High School                    91.55           89.71
#
#                       % Passing Reading  Average Math Score  \
#
# Bailey High School                 79.3                76.6
# Cabrera High School                93.9                83.8
# Figueroa High School               78.4                83.1
# Ford High School                   77.5                83.3
# Griffin High School                93.4                83.4
#
#                       Average Reading Score  Per Student Budget School Type  \
#
# Bailey High School                     81.2                 628    District
# Cabrera High School                    83.8                 582     Charter
# Figueroa High School                   84.0                 639    District
# Ford High School                       84.0                 644    District
# Griffin High School                    83.8                 625     Charter
#
#                      Total School Budget Total Students  \
#
# Bailey High School            $3,124,928          4,976
# Cabrera High School           $1,081,356          1,858
# Figueroa High School          $1,884,411          2,949
# Ford High School              $1,763,916          2,739
# Griffin High School             $917,500          1,468
#
#                      Spending Ranges (Per Student)
#
# Bailey High School                        $610-635
# Cabrera High School                         $0-585
# Figueroa High School                      $635-660
# Ford High School                          $635-660
# Griffin High School                       $610-635

# %%
grouped_bycost = school_summary_data.groupby("Spending Ranges (Per Student)")
grouped_bycost.mean()
# Out:
#                                % Overall Passing Rate  % Passing Math  \
# Spending Ranges (Per Student)
# $0-585                                      91.837500       90.350000
# $585-610                                    91.595000       90.785000
# $610-635                                    81.760000       77.170000
# $635-660                                    74.114286       67.957143
#
#                                % Passing Reading  Average Math Score  \
# Spending Ranges (Per Student)
# $0-585                                 93.325000           78.750000
# $585-610                               92.400000           80.250000
# $610-635                               86.350000           80.000000
# $635-660                               80.257143           81.571429
#
#                                Average Reading Score  Per Student Budget
# Spending Ranges (Per Student)
# $0-585                                     81.600000               581.0
# $585-610                                   82.600000               604.5
# $610-635                                   82.500000               626.5
# $635-660                                   83.028571               645.0
