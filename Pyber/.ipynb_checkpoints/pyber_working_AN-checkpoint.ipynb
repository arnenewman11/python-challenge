# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import seaborn as sns

# %%
#call raw data files
city_path= "raw_data/city_data.csv"
ride_path = "raw_data/ride_data.csv"

#read raw data files into dataframes
city_data = pd.read_csv(city_path)
ride_data = pd.read_csv(ride_path)

#sorted_city_data = city_data.sort("city", inplace = True)

city_data_df = pd.DataFrame(city_data)
ride_data_df = pd.DataFrame(ride_data)

#Attempted to ort these by city name... hasn't been working
#city_data_df = city_data_df.sort_values("city", inplace = True)
#ride_data_df = ride_data_df.sort_values("city", inplace = True)
print(len(ride_data_df))
#preview the data frame
city_data_df.head()
# Out:
# 2375
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
#preview the data frame
ride_data_df.head()
# Out:
#           city                 date   fare        ride_id
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673

# %%
all_data = pd.merge(ride_data, city_data, how="left", on="city")

#compare the length of all_data and ride_data... it looks like there are 32 cities with no ride data, so they have blank rows
#(due to the outer join)
print(len(all_data))
print(len(ride_data))
all_data.head()
#list(all_data)
# Out:
# 2407
# 2375
#           city                 date   fare        ride_id  driver_count   type
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46  Urban
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35  Urban
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55  Urban
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68  Urban
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8  Urban

# %%
#create three separate data sets by type
urban_data = all_data[all_data["type"] == "Urban"]

suburban_data = all_data[all_data["type"] == "Suburban"]

rural_data = all_data[all_data["type"] == "Rural"]

# %%
#plot urban data
plt.scatter(urban_data.groupby(["city"]).count()["fare"], urban_data.groupby(["city"]).mean()["fare"], 
            s = urban_data.groupby(["city"]).mean()["driver_count"], 
            alpha = .5, label = "Urban", c = "firebrick", edgecolor = "darkgrey")

#plot suburban data
plt.scatter(suburban_data.groupby(["city"]).count()["fare"], suburban_data.groupby(["city"]).mean()["fare"], 
            s = suburban_data.groupby(["city"]).mean()["driver_count"], 
            alpha = .5, label = "Suburban", c = "dodgerblue", edgecolor = "darkgrey")

#plot rural data
plt.scatter(rural_data.groupby(["city"]).count()["fare"], rural_data.groupby(["city"]).mean()["fare"], 
            s = rural_data.groupby(["city"]).mean()["driver_count"], 
            alpha = .5, label = "Rural", c = "darkturquoise", edgecolor = "darkgrey")

plt.xlabel("Total Number of Rides per City")
plt.ylabel("Average Fare ($) per City")
plt.title("Pyber Ride Sharing Data (2016)")
plt.legend(loc="best")


plt.show()
#average_fare.head()

# %%
#what is going on here? I can't get city_data sorted, and can't pull the specific columns that I want
grouped_data = all_data.groupby(["city","type"])
#type(grouped_data)
grouped_data.mean()
#grouped_data_df = pd.DataFrame(grouped_data.mean())

#BELOW IS MY VARIABLE FOR AVERAGE FARE and DRIVER COUNT
#pd.DataFrame(grouped_data["fare"].mean())
#grouped_data["driver_count"].mean()
# Out:
#                                     fare       ride_id  driver_count
# city                 type
# Alvarezhaven         Urban     23.928710  5.351586e+12          21.0
# Alyssaberg           Urban     20.609615  3.536678e+12          67.0
# Anitamouth           Suburban  37.315556  4.195870e+12          16.0
# Antoniomouth         Urban     23.625000  5.086800e+12          21.0
# Aprilchester         Urban     21.981579  4.574788e+12          49.0
# Arnoldview           Urban     25.106452  5.021952e+12          41.0
# Campbellport         Suburban  33.711333  5.805424e+12          26.0
# Carrollbury          Suburban  36.606000  4.274615e+12           4.0
# Carrollfort          Urban     25.395517  4.759008e+12          55.0
# Clarkstad            Suburban  31.051667  6.682745e+12          21.0
# Conwaymouth          Suburban  34.591818  4.391649e+12          18.0
# Davidtown            Urban     22.978095  5.850005e+12          73.0
# Davistown            Urban     21.497200  4.361977e+12          25.0
# East Cherylfurt      Suburban  31.416154  3.981187e+12           9.0
# East Douglas         Urban     26.169091  4.732315e+12          12.0
# East Erin            Urban     24.478214  5.226259e+12          43.0
# East Jenniferchester Suburban  32.599474  5.933107e+12          22.0
# East Leslie          Rural     33.660909  6.051052e+12           9.0
# East Stephen         Rural     39.053000  5.306327e+12           6.0
# East Troybury        Rural     33.244286  5.948234e+12           3.0
# Edwardsbury          Urban     26.876667  5.296117e+12          11.0
# Erikport             Rural     30.043750  6.883015e+12           3.0
# Eriktown             Urban     25.478947  4.113171e+12          15.0
# Floresberg           Suburban  32.310000  2.630319e+12           7.0
# Fosterside           Urban     23.034583  5.101131e+12          69.0
# Hernandezshire       Rural     32.002222  5.206210e+12          10.0
# Horneland            Rural     21.482500  5.351789e+12           8.0
# Jacksonfort          Rural     32.006667  4.610855e+12           6.0
# Jacobfort            Urban     24.779355  4.099091e+12          52.0
# Jasonfort            Suburban  27.831667  6.439182e+12          25.0
# ...                                  ...           ...           ...
# South Roy            Urban     26.031364  4.862249e+12          35.0
# South Shannonborough Suburban  26.516667  4.824875e+12           9.0
# Spencertown          Urban     23.681154  4.850559e+12          68.0
# Stevensport          Rural     31.948000  3.125721e+12           6.0
# Stewartview          Urban     21.614000  4.936695e+12          49.0
# Swansonbury          Urban     27.464706  4.443028e+12          64.0
# Thomastown           Suburban  30.308333  4.525633e+12           1.0
# Tiffanyton           Suburban  28.510000  4.968458e+12          21.0
# Torresshire          Urban     24.207308  5.117907e+12          70.0
# Travisville          Urban     27.220870  3.317507e+12          37.0
# Vickimouth           Urban     21.474667  4.242738e+12          13.0
# Webstertown          Suburban  29.721250  4.401465e+12          26.0
# West Alexis          Urban     19.523000  5.133766e+12          47.0
# West Brandy          Urban     24.157667  4.673435e+12          12.0
# West Brittanyton     Urban     25.436250  5.796976e+12           9.0
# West Dawnfurt        Urban     22.330345  5.119541e+12          34.0
# West Evan            Suburban  27.013333  5.445616e+12           4.0
# West Jefferyfurt     Urban     21.072857  3.614437e+12          65.0
# West Kevintown       Rural     21.528571  7.002171e+12           5.0
# West Oscar           Urban     24.280000  4.525743e+12          11.0
# West Pamelaborough   Suburban  33.799286  4.081521e+12          27.0
# West Paulport        Suburban  33.278235  4.895520e+12           5.0
# West Peter           Urban     24.875484  4.630766e+12          61.0
# West Sydneyhaven     Urban     22.368333  4.432234e+12          70.0
# West Tony            Suburban  29.609474  5.080147e+12          17.0
# Williamchester       Suburban  34.278182  5.679295e+12          26.0
# Williamshire         Urban     26.990323  4.937704e+12          70.0
# Wiseborough          Urban     22.676842  6.046575e+12          55.0
# Yolandafurt          Urban     27.205500  4.870867e+12           7.0
# Zimmermanmouth       Urban     28.301667  4.618734e+12          45.0
#
# [125 rows x 3 columns]

# %%
#

# %%
list(all_data)
# Out:
# ['city', 'date', 'fare', 'ride_id', 'driver_count', 'type']
